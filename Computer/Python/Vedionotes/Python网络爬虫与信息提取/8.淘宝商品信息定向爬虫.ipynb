# %% [markdown]
# # 淘宝商品信息定向爬虫

# %% [markdown]
# - 目标：获取淘宝搜索页面的信息，提取其中的商品名称和价格
# - 理解：
#     淘宝的搜索接口
#     翻页的处理
# - 技术路线：requests‐bs4‐re

# %% [markdown]
# ** 程序的结构设计 **
#
# - 步骤1：提交商品搜索请求，循环获取页面
# - 步骤2：对于每个页面，提取商品名称和价格信息
# - 步骤3：将信息输出到屏幕上

# %%
import requests
import re

# %%
def getHTMLText(url):
    try:
        r = requests.get(url, timeout = 30)
        r.raise_for_status()
        r.encoding = r.apparent_encoding
        return r.text
    except:
        return ""

# %%
def parsePage(ilt, html):
    try:
        plt = re.findall(r'\"view_price\"\:\"[\d\.]*\"', html)
        tlt = re.findall(r'\"raw_title\"\:\".*?\"', html)
        for i in range(len(plt)):
            price = eval(plt[i].split(':')[1])
            title = eval(tlt[i].split(':')[1])
            ilt.append([price, title])
    except:
        print("")

# %%
def printGoodsList(ilt):
    tplt = "{:4}\t{:8}\t{:16}"
    print(tplt.format("序号", "价格",  "商品名称"))
    count = 0
    for g in ilt:
        count = count + 1
        print(tplt.format(count, g[0], g[1]))

# %%
def main():
    goods = '书包'
    depth = 2
    start_url = 'https://s.taobao.com/search?q=' + goods
    infoList = []
    for i in range(depth):
        try:
            url = start_url + '&s=' + str(44*i)
            html = getHTMLText(url)
            parsePage(infoList, html)
        except:
            continue
    printGoodsList(infoList)

# %%
main()
# Out:
# 序号  	价格      	商品名称
#    1	129.00  	瑞士军刀旅行双肩包男中学生书包电脑背包
#    2	69.00   	男士双肩包韩版时尚潮流旅行背包日韩个性街头大学生高中学生书包
#    3	69.90   	木村耀司旅行背包大容量韩版休闲电脑包简约书包学生潮流双肩包男
#    4	209.00  	现货 JUST HYPE 英国代购正品黑白彩色喷墨双肩包男女中学生书包
#    5	84.60   	尼龙双肩包2017新款韩版牛津布背包妈咪包大容量书包旅游双肩背包
#    6	1710.70 	双肩包男潮韩版皮男士背包旅行包商务休闲包男包时尚学生书包防水
#    7	22.49   	帆布双肩包女包日韩版潮高中学生书包女旅行背包校园小清新学院风
#    8	158.00  	羊皮双肩包女韩版潮学院风书包大小号简约真皮背包休闲旅游女包包
#    9	253.00  	欧美背包街头滑板包双肩背包登山包男女糖果色运动双肩学生书包
#   10	95.00   	减负护脊双肩风可爱2-6小学生公主女孩书包韩版儿童年级
#   11	79.00   	日本购儿童防走失背包  宝宝可爱幼儿1-3岁小恶魔书包带牵引绳包
#   12	26.90   	季新款双肩女包淘气猫双背新款电脑包校园风学生书包邮2016夏
#   13	26.89   	日韩版双肩包男女百搭中学生书包学院风刺绣帆布包纯色简约包包女
#   14	196.80  	新款韩版男包双肩包帆布包 休闲男士背包时尚潮流学生书包旅行包
#   15	399.00  	日本代购新款双肩包条纹拼接书包电脑包男女大容量旅行背包
#   16	39.90   	小学生书包1-3-4-5-6年级男生儿童超轻防水护脊女童双肩背包周岁2
#   17	50.00   	日韩版潮大容量双肩包学生帆布书包男女情侣旅行背包15.6寸电脑包
