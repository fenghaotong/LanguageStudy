# %% [markdown]
# # 处理文本
#
# - [X] 文本介绍
# - [X] 基本文本命令
# - [X] 文本属性和布局
# - [X] 默认字体
# - [X] 注释
# - [X] 写作的数学表达式
# - [X] 文本呈现与乳胶
# - [X] 排版与 XeLaTeX/LuaLaTeX

# %% [markdown]
# ## 文本介绍
#
# - matplotlib 具有广泛的文本支持，包括支持数学表达式

# %% [markdown]
# ## 基本的文本命令

# %% [markdown]
# ** 以下命令用于在pyplot界面中创建文本 **
#
# - text(): 将文本添加到任意位置
# - xlable(): 将标签添加到x轴
# - ylable(): 将标签添加到y轴
# - title(): 添加到标题
# - figtext(): 将文本添加到任意位置
# - suptitle(): 添加到标题
# - anntate(): 添加批注

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
fig.suptitle('bold figure suptitle', fontsize = 14, fontweight = 'bold')

# %%
#help(fig.add_subplot)

# %%
ax = fig.add_subplot(111)

# %%
ax

# %%
fig.subplots_adjust(top = 0.85)

# %%
ax.set_title('axes title')

# %%
ax.set_xlabel('xlable')
ax.set_ylabel('ylable')

# %%
ax.text(3, 8, 'boxed italics text in data coords', style = 'italic', 
        bbox = {'facecolor':'red', 'alpha':0.5, 'pad':10})
ax.text(2, 6, r'an equation: $E=mc^2$', fontsize=15)

ax.text(3, 2, u'unicode: Institut f\374r Festk\366rperphysik')

ax.text(0.95, 0.01, 'colored text in axes coords',
        verticalalignment='bottom', horizontalalignment='right',
        transform=ax.transAxes,
        color='green', fontsize=15)

# %%
ax.plot([2], [1], 'o')
ax.annotate('annotate', xy=(2, 1), xytext=(3, 4),
            arrowprops=dict(facecolor='black', shrink=0.05))

ax.axis([0, 10, 0, 10])
# Out:
# [0, 10, 0, 10]

# %%
plt.show()

# %%
# -*- coding: utf-8 -*-
import matplotlib.pyplot as plt

fig = plt.figure()
fig.suptitle('bold figure suptitle', fontsize=14, fontweight='bold')

ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.85)
ax.set_title('axes title')

ax.set_xlabel('xlabel')
ax.set_ylabel('ylabel')

ax.text(3, 8, 'boxed italics text in data coords', style='italic',
        bbox={'facecolor':'red', 'alpha':0.5, 'pad':10})

ax.text(2, 6, r'an equation: $E=mc^2$', fontsize=15)

ax.text(3, 2, u'unicode: Institut f\374r Festk\366rperphysik')

ax.text(0.95, 0.01, 'colored text in axes coords',
        verticalalignment='bottom', horizontalalignment='right',
        transform=ax.transAxes,
        color='green', fontsize=15)


ax.plot([2], [1], 'o')
ax.annotate('annotate', xy=(2, 1), xytext=(3, 4),
            arrowprops=dict(facecolor='black', shrink=0.05))

ax.axis([0, 10, 0, 10])

plt.show()

# %% [markdown]
# ## 文本属性和布局

# %% [markdown]
# - Matplotlib.text.Text实例具有的各种属性，可以通过文本命令 （例如， title()， xlabel()的关键字参数配置和text （）)。

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
left, width = .25, .5
bottom, height = .25, .5
right = left + width
top = bottom + height

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

# %%
p = patches.Rectangle(
    (left, bottom), width, height,
    fill=False, transform=ax.transAxes, clip_on=False
)

# %%
ax.add_patch(p)

# %%
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.text(left, bottom, 'left top',
        horizontalalignment='left',
        verticalalignment='top',
        transform=ax.transAxes)
p = patches.Rectangle(
    (left, bottom), width, height,
    fill=False, transform=ax.transAxes, clip_on=False
)
ax.add_patch(p)
ax.set_axis_off()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.text(left, bottom, 'left bottom',
        horizontalalignment='left',
        verticalalignment='bottom',
        transform=ax.transAxes)
p = patches.Rectangle(
    (left, bottom), width, height,
    fill=False, transform=ax.transAxes, clip_on=False
)
ax.add_patch(p)
ax.set_axis_off()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.text(right, top, 'right bottom',
        horizontalalignment='right',
        verticalalignment='bottom',
        transform=ax.transAxes)
p = patches.Rectangle(
    (left, bottom), width, height,
    fill=False, transform=ax.transAxes, clip_on=False
)
ax.add_patch(p)
ax.set_axis_off()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.text(right, top, 'right top',
        horizontalalignment='right',
        verticalalignment='top',
        transform=ax.transAxes)
p = patches.Rectangle(
    (left, bottom), width, height,
    fill=False, transform=ax.transAxes, clip_on=False
)
ax.add_patch(p)
ax.set_axis_off()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.text(right, bottom, 'center top',
        horizontalalignment='center',
        verticalalignment='top',
        transform=ax.transAxes)
p = patches.Rectangle(
    (left, bottom), width, height,
    fill=False, transform=ax.transAxes, clip_on=False
)
ax.add_patch(p)
ax.set_axis_off()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.text(left, 0.5*(bottom+top), 'right center',
        horizontalalignment='right',
        verticalalignment='center',
        rotation='vertical',
        transform=ax.transAxes)
p = patches.Rectangle(
    (left, bottom), width, height,
    fill=False, transform=ax.transAxes, clip_on=False
)
ax.add_patch(p)
ax.set_axis_off()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.text(left, 0.5*(bottom+top), 'left center',
        horizontalalignment='left',
        verticalalignment='center',
        rotation='vertical',
        transform=ax.transAxes)
p = patches.Rectangle(
    (left, bottom), width, height,
    fill=False, transform=ax.transAxes, clip_on=False
)
ax.add_patch(p)
ax.set_axis_off()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.text(0.5*(left+right), 0.5*(bottom+top), 'middle',
        horizontalalignment='center',
        verticalalignment='center',
        fontsize=20, color='red',
        transform=ax.transAxes)
p = patches.Rectangle(
    (left, bottom), width, height,
    fill=False, transform=ax.transAxes, clip_on=False
)
ax.add_patch(p)
ax.set_axis_off()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.text(right, 0.5*(bottom+top), 'centered',
        horizontalalignment='center',
        verticalalignment='center',
        rotation='vertical',
        transform=ax.transAxes)
p = patches.Rectangle(
    (left, bottom), width, height,
    fill=False, transform=ax.transAxes, clip_on=False
)
ax.add_patch(p)
ax.set_axis_off()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.text(left, top, 'rotated\nwith newlines',
        horizontalalignment='center',
        verticalalignment='center',
        rotation=45,
        transform=ax.transAxes)
p = patches.Rectangle(
    (left, bottom), width, height,
    fill=False, transform=ax.transAxes, clip_on=False
)
ax.add_patch(p)
ax.set_axis_off()
plt.show()

# %% [markdown]
# ## 注释

# %% [markdown]
# ### 基本注释

# %% [markdown]
# - 基本的text()的使用将文本放在轴上的任意位置
# - annotate

# %%
#help(ax.annotate)

# %%
import numpy as np

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = ax.plot(t, s, lw=2)#线条粗细

# %%
ax.annotate('local max', xy=(2,1), xytext=(3, 1.5), #xytext是指向线的方向
           arrowprops=dict(facecolor='black', shrink=0.05),
           )

# %%
ax.set_ylim(-2,2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111, polar=True)
r = np.arange(0,1,0.001)
theta = 2*2*np.pi*r
line, = ax.plot(theta, r, color='#ee8d18', lw=3)

# %%
ind = 800
thisr, thistheta = r[ind], theta[ind]
ax.plot([thistheta], [thisr], 'o')
ax.annotate('a polar annotation',
            xy=(thistheta, thisr),  # theta, radius
            xytext=(0.05, 0.05),    # fraction, fraction
            textcoords='figure fraction',
            arrowprops=dict(facecolor='black', shrink=0.05),
            horizontalalignment='left',
            verticalalignment='bottom',
            )

# %%
plt.show()

# %%
import numpy.random
import matplotlib.pyplot as plt

fig = plt.figure(1, figsize=(5,5))
fig.clf()

# %%
#help(fig.clf)

# %%
#help(plt.figure)

# %%
ax = fig.add_subplot(111)
ax.set_aspect(1)

# %%
#help(ax.set_aspect)

# %%
x1 = -1 + numpy.random.randn(100)
y1 = -1 + numpy.random.randn(100)
x2 = 1. + numpy.random.randn(100)
y2 = 1. + numpy.random.randn(100)

# %%
ax.scatter(x1, y1, color="r")
ax.scatter(x2, y2, color="g")

# %%
bbox_props = dict(boxstyle="round", fc="w", ec="0.5", alpha=0.9)
ax.text(-2, -2, "Sample A", ha="center", va="center", size=20,
        bbox=bbox_props)
ax.text(2, 2, "Sample B", ha="center", va="center", size=20,
        bbox=bbox_props)


bbox_props = dict(boxstyle="rarrow", fc=(0.8,0.9,0.9), ec="b", lw=2)
t = ax.text(0, 0, "Direction", ha="center", va="center", rotation=45,
            size=15,
            bbox=bbox_props)

bb = t.get_bbox_patch()
bb.set_boxstyle("rarrow", pad=0.6)

# %%
ax.set_xlim(-4, 4)
ax.set_ylim(-4, 4)

plt.draw()
plt.show()

# %%
import numpy.random
import matplotlib.pyplot as plt

fig = plt.figure(1, figsize=(5,5))
fig.clf()

ax = fig.add_subplot(111)
ax.set_aspect(1)

x1 = -1 + numpy.random.randn(100)
y1 = -1 + numpy.random.randn(100)
x2 = 1. + numpy.random.randn(100)
y2 = 1. + numpy.random.randn(100)

ax.scatter(x1, y1, color="r")
ax.scatter(x2, y2, color="g")

bbox_props = dict(boxstyle="round", fc="w", ec="0.5", alpha=0.9)
ax.text(-2, -2, "Sample A", ha="center", va="center", size=20,
        bbox=bbox_props)
ax.text(2, 2, "Sample B", ha="center", va="center", size=20,
        bbox=bbox_props)


bbox_props = dict(boxstyle="rarrow", fc=(0.8,0.9,0.9), ec="c", lw=2)
t = ax.text(0, 0, "Direction", ha="center", va="center", rotation=45,
            size=15,
            bbox=bbox_props)

bb = t.get_bbox_patch()
bb.set_boxstyle("rarrow", pad=0.6)

ax.set_xlim(-4, 4)
ax.set_ylim(-4, 4)

plt.draw()
plt.show()

# %% [markdown]
# ## 写作的数学表达式
#
# - LaTex在python中的写法

# %%
plt.title(r'$alpha > beta$')

# %%
plt.show()

# %% [markdown]
# ### 下标和上标

# %%
plt.title(r'$\sum_{i=0}^{10} x_i$')

# %%
plt.show()

# %% [markdown]
# ### 分数、 勺和堆叠式的数

# %%
plt.title(r'$\frac{3}{4} \binom{3}{4} \stackrel{3}{4}$')
plt.show()

# %%
plt.title(r'$\frac{5 - \frac{1}{x}}{4}$')
plt.show()

# %%
plt.title(r'$\left(\frac{5 - \frac{1}{x}}{4}\right)$')
plt.show()

# %% [markdown]
# ### 基

# %%
plt.title(r'$\sqrt[3]{x}$')
plt.show()

# %% [markdown]
# ### 符号
#
# - http://matplotlib.org/users/mathtext.html
